# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfnchb/0021_Group-Prototype/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt==1.5.1
# Out:
# Collecting paho-mqtt==1.5.1
#   Downloading paho-mqtt-1.5.1.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.5.1-py3-none-any.whl size=61549 sha256=89df19ac7fb931461f937eaddcb876785f2aa846a2aceda18cd131b4b3ac77c0
#   Stored in directory: /root/.cache/pip/wheels/b6/72/f9/44ca415a44f9cc7468fe4c59e6282938e504fadec09641fa63
# Successfully built paho-mqtt
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-1.5.1

# %%
import paho.mqtt.client as mqtt
import requests
import json
import time

# MQTT Broker 的配置信息
mqtt_broker = "mqtt.cetools.org"
mqtt_topic = "student/ucfnhy0/tide"
username = "student"  # 替换为您的MQTT用户名
password = "ce2021-mqtt-forget-whale"  # 替换为您的MQTT密码

# 记录上次的潮位，用于在无法获取新数据时使用
last_tidal_level = None

# 获取Newhaven潮位监测站数据
measure_id = "E73139-level-tidal_level-Mean-15_min-mAOD"
api_url = f'http://environment.data.gov.uk/flood-monitoring/id/measures/{measure_id}/readings?latest'

def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to MQTT Broker!")
    else:
        print(f"Failed to connect, return code {rc}")
    client.subscribe(mqtt_topic)

def on_message(client, userdata, msg):
    print(f"Received message '{msg.payload.decode()}' on topic '{msg.topic}' with QoS {msg.qos}")

def update_and_publish_tidal_level():
    global last_tidal_level
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            data = response.json()
            if 'items' in data and data['items']:
                tidal_level = data['items'][0].get('value')
                last_tidal_level = tidal_level  # 更新最后的潮位信息
            else:
                print("No new data, using last known tidal level.")
        else:
            print(f"API request failed with status code: {response.status_code}, using last known tidal level.")
    except Exception as e:
        print(f"Error fetching tidal level: {e}")

    # 使用最后已知的潮位信息进行发布
    if last_tidal_level is not None:
        print(f"Publishing tidal level: {last_tidal_level}")
        client.publish(mqtt_topic, payload=last_tidal_level, qos=0)
    else:
        print("No tidal level data available to publish.")

# 创建MQTT客户端实例
client = mqtt.Client(protocol=mqtt.MQTTv311)
client.username_pw_set(username, password)  # 设置MQTT用户名和密码

# 设置回调函数
client.on_connect = on_connect
client.on_message = on_message

# 尝试连接MQTT Broker
try:
    client.connect(mqtt_broker, 1884, 60)
    client.loop_start()
except Exception as e:
    print(f"Error connecting to MQTT Broker: {e}")
    exit(1)

# 使用定时循环来定期更新潮位信息
while True:
    update_and_publish_tidal_level()
    time.sleep(360)  # 每隔10分钟更新一次
# Out:
# Connected to MQTT Broker!
# Publishing tidal level: 0.891
# Received message '0.891' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.891
# Received message '0.891' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.891
# Received message '0.891' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '-1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '-1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.715
# Received message '0.715' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.715
# Received message '0.715' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.565
# Received message '0.565' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.565
# Received message '0.565' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.565
# Received message '0.565' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.368
# Received message '0.368' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.368
# Received message '0.368' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.219
# Received message '0.219' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.219
# Received message '0.219' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.219
# Received message '0.219' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.039
# Received message '0.039' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: 0.039
# Received message '0.039' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.105
# Received message '-0.105' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.105
# Received message '-0.105' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.105
# Received message '-0.105' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.239
# Received message '-0.239' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.239
# Received message '-0.239' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.354
# Received message '-0.354' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.354
# Received message '-0.354' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.354
# Received message '-0.354' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.46
# Received message '-0.46' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.46
# Received message '-0.46' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.533
# Received message '-0.533' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '-1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.533
# Received message '-0.533' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.533
# Received message '-0.533' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.62
# Received message '-0.62' on topic 'student/ucfnhy0/tide' with QoS 0
# Received message '1
#
# ' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.62
# Received message '-0.62' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.679
# Received message '-0.679' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.679
# Received message '-0.679' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.679
# Received message '-0.679' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.711
# Received message '-0.711' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.711
# Received message '-0.711' on topic 'student/ucfnhy0/tide' with QoS 0
# Publishing tidal level: -0.761
# Received message '-0.761' on topic 'student/ucfnhy0/tide' with QoS 0
